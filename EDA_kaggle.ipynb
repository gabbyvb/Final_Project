# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("Raw Data/DC_data.csv")
# Out:
# C:\Users\FrantheMan\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = pd.DataFrame(data)

# %%
df.head(50)
# Out:
#     Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
df.shape
# Out:
# (158957, 49)

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.PRICE.isna().sum()
# Out:
# 60741

# %%
df.NATIONALGRID.isna().sum()
# Out:
# 52906

# %%
df.LATITUDE.isna().sum()
# Out:
# 1

# %%
df.LONGITUDE.isna().sum()
# Out:
# 1

# %%
df.FIREPLACES.isna().sum()
# Out:
# 0

# %%
df.LANDAREA.isna().sum()
# Out:
# 0

# %%
df.ASSESSMENT_NBHD.value_counts()
# Out:
# Old City 2                      15978
# Old City 1                      15000
# Columbia Heights                 9474
# Brookland                        6568
# Petworth                         6323
# Deanwood                         5983
# Chevy Chase                      5354
# Congress Heights                 4729
# Brightwood                       4112
# Mt. Pleasant                     4052
# Capitol Hill                     3830
# Georgetown                       3774
# Hillcrest                        3734
# Randle Heights                   3517
# Fort Dupont Park                 3425
# Kalorama                         3207
# Central-tri 1                    3132
# Cleveland Park                   3032
# Trinidad                         2964
# Southwest Waterfront             2828
# Riggs Park                       2795
# Woodridge                        2748
# American University              2594
# Central-tri 3                    2500
# Eckington                        2328
# ...

# %%
df.LANDAREA.value_counts()
# Out:
# 1800     1071
# 2000     1020
# 4000      848
# 5000      833
# 1600      792
#          ...
# 10321       1
# 12933       1
# 15289       1
# 10883       1
# 17968       1
# Name: LANDAREA, Length: 11359, dtype: int64

# %%
df.NATIONALGRID.value_counts()
# Out:
# 18S UJ 28233 01950    5
# 18S UJ 28168 01936    5
# 18S UJ 25398 04622    4
# 18S UJ 28045 01888    4
# 18S UJ 28025 01949    4
#                      ..
# 18S UJ 21215 14863    1
# 18S UJ 21235 14889    1
# 18S UJ 21208 14842    1
# 18S UJ 21223 14875    1
# 18S UH 25804 98859    1
# Name: NATIONALGRID, Length: 105949, dtype: int64

# %%
df.LIVING_GBA.isna().sum()
# Out:
# 106696

# %%
df.AC.value_counts()
# Out:
# Y    114620
# N     44272
# 0        65
# Name: AC, dtype: int64

# %%
df.WARD.value_counts()
# Out:
# Ward 6    23973
# Ward 3    23688
# Ward 4    22202
# Ward 2    22167
# Ward 5    21359
# Ward 1    17455
# Ward 7    17206
# Ward 8    10906
# Name: WARD, dtype: int64

# %%
df.QUADRANT.value_counts()
# Out:
# NW    89736
# NE    37675
# SE    27224
# SW     4085
# Name: QUADRANT, dtype: int64

# %%
df.QUALIFIED.value_counts()
# Out:
# U    82608
# Q    76349
# Name: QUALIFIED, dtype: int64

# %%
df.ASSESSMENT_SUBNBHD.value_counts()
# Out:
# 040 D Old City 2       4403
# 040 E Old City 2       2968
# 040 C Old City 2       2886
# 042 B Petworth         2763
# 039 K Old City 1       2640
#                        ...
# 050 A Spring Valley     176
# 004 C Berkley           154
# 025 A Georgetown        140
# 050 D Spring Valley     131
# 025 C Georgetown         91
# Name: ASSESSMENT_SUBNBHD, Length: 121, dtype: int64

# %%
df.HEAT.value_counts()
# Out:
# Forced Air        53972
# Hot Water Rad     47202
# Warm Cool         33628
# Ht Pump           21412
# Wall Furnace       1120
# Water Base Brd      402
# Elec Base Brd       351
# No Data             330
# Electric Rad        144
# Gravity Furnac      140
# Air-Oil             117
# Evp Cool             50
# Ind Unit             50
# Air Exchng           39
# Name: HEAT, dtype: int64

# %%
df.KITCHENS.isna().sum()
# Out:
# 52262

# %%
df.CITY.value_counts()
# Out:
# WASHINGTON    106051
# Name: CITY, dtype: int64

# %%
df.STYLE.value_counts()
# Out:
# 2 Story            81137
# 3 Story             9449
# 2.5 Story Fin       7000
# 1 Story             4420
# 1.5 Story Fin       2655
# 2.5 Story Unfin      729
# 4 Story              369
# Split Level          303
# Split Foyer          279
# 3.5 Story Fin        133
# 1.5 Story Unfin      112
# Default               65
# Bi-Level              19
# 4.5 Story Fin         13
# 3.5 Story Unfin        8
# Vacant                 2
# 4.5 Story Unfin        2
# Outbuildings           1
# Name: STYLE, dtype: int64

# %%
price_data = df.PRICE
heat_data = df.HEAT
Bed_data = df.BEDRM
fire_data = df.FIREPLACES

# %%
plt.scatter(price_data,heat_data)

# %%
plt.scatter(price_data,heat_data)

# %%
plt.scatter(fire_data, price_data)

# %%
sns.pairplot(df[['ROOMS','BATHRM','HF_BATHRM','BEDRM','KITCHENS', 'FIREPLACES']], kind="scatter", diag_kind = 'kde', plot_kws = {'alpha': 0.33, 's': 80, 'edgecolor': 'k'}, size = 4)
plt.show()
# Out:
# C:\Users\FrantheMan\anaconda3\envs\mlenv\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df = df[( (df["ROOMS"]<100) & (df["ROOMS"]>=df["BEDRM"]) & (df["BATHRM"]<24) & (df['FIREPLACES']<5) & (df['KITCHENS']<3) )]

# %%
imp_df = df[['BATHRM','HF_BATHRM', 'AC', 'ROOMS', 'BEDRM', 'SALEDATE', 'KITCHENS', 'FIREPLACES', 'LANDAREA', 'LONGITUDE', 'LATITUDE', 'QUADRANT', 'PRICE','ZIPCODE','WARD']]
imp_df.head()
# Out:
#    BATHRM  HF_BATHRM AC  ROOMS  BEDRM        SALEDATE  KITCHENS  FIREPLACES  \
# 1       3          1  Y     11      5  8/17/2000 0:00       2.0           4
# 2       3          1  Y      9      5  6/21/2016 0:00       2.0           4
# 3       3          1  Y      8      5  7/12/2006 0:00       2.0           3
# 4       2          1  Y     11      3             NaN       1.0           0
# 5       3          2  Y     10      5  2/26/2010 0:00       1.0           4
#
#    LANDAREA  LONGITUDE   LATITUDE QUADRANT      PRICE  ZIPCODE    WARD
# 1      1680 -77.040764  38.914683       NW        NaN  20009.0  Ward 2
# 2      1680 -77.040678  38.914684       NW  2100000.0  20009.0  Ward 2
# 3      1680 -77.040629  38.914683       NW  1602000.0  20009.0  Ward 2
# 4      2032 -77.039361  38.914383       NW        NaN  20009.0  Ward 2
# 5      2196 -77.039715  38.914331       NW  1950000.0  20009.0  Ward 2

# %%
imp_df['SALEDATE'] = imp_df['SALEDATE'].astype('datetime64[ns]')
# Out:
# C:\Users\FrantheMan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
imp_df['SALEDATE'] = imp_df['SALEDATE'].values.astype('datetime64[Y]')
# Out:
# C:\Users\FrantheMan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
imp_df['SALEDATE'] = pd.DatetimeIndex(df['SALEDATE']).year
# Out:
# C:\Users\FrantheMan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
imp_df.dtypes
# Out:
# BATHRM          int64
# HF_BATHRM       int64
# AC             object
# ROOMS           int64
# BEDRM           int64
# SALEDATE      float64
# KITCHENS      float64
# FIREPLACES      int64
# LANDAREA        int64
# LONGITUDE     float64
# LATITUDE      float64
# QUADRANT       object
# PRICE         float64
# ZIPCODE       float64
# WARD           object
# dtype: object

# %%
imp_df.shape
# Out:
# (101974, 15)

# %%
#Dropping NaNs
imp_df = imp_df.dropna()
imp_df.head(50)
# Out:
#      BATHRM  HF_BATHRM AC  ROOMS  BEDRM  SALEDATE  KITCHENS  FIREPLACES  \
# 2         3          1  Y      9      5    2016.0       2.0           4
# 3         3          1  Y      8      5    2006.0       2.0           3
# 5         3          2  Y     10      5    2010.0       1.0           4
# 7         3          1  Y      8      4    2011.0       2.0           1
# 8         3          1  Y      7      3    2018.0       2.0           1
# 14        3          1  Y      5      3    2011.0       2.0           1
# 16        3          1  Y      8      3    2010.0       1.0           0
# 19        3          1  Y      9      3    2001.0       2.0           1
# 20        3          1  Y     14      5    2016.0       1.0           3
# 22        1          0  Y      6      3    2006.0       1.0           0
# 23        2          1  Y      5      3    2012.0       1.0           1
# 24        2          1  Y      8      3    2012.0       1.0           2
# ...

# %%
imp_df.shape
# Out:
# (55028, 15)

# %%
# Loading to csv
imp_df.to_csv('C:/Users/FrantheMan/Desktop/Classwork/Final_Project/Raw Data/clean_house_data.csv', index = False)

# %%
imp_df['SALEDATE'].min()
# Out:
# 1982.0

# %%
imp_df['SALEDATE'].max()
# Out:
# 2018.0

# %%
imp_df['KITCHENS'].max()
# Out:
# 2.0

# %%
imp_df.dtypes
# Out:
# BATHRM          int64
# HF_BATHRM       int64
# AC             object
# ROOMS           int64
# BEDRM           int64
# STORIES       float64
# SALEDATE      float64
# KITCHENS      float64
# FIREPLACES      int64
# LANDAREA        int64
# LONGITUDE     float64
# LATITUDE      float64
# QUADRANT       object
# PRICE         float64
# ZIPCODE       float64
# dtype: object

# %%
prime_data = pd.read_csv('Raw Data/PRIME_data.csv')

# %%
prime_df = pd.DataFrame(prime_data)
prime_df
# Out:
#      DATE  PRIME
# 0    1982  16.50
# 1    1982  17.00
# 2    1982  16.50
# 3    1982  16.00
# 4    1982  15.50
# ..    ...    ...
# 122  2018   5.25
# 123  2018   5.50
# 124  2019   5.25
# 125  2019   5.00
# 126  2019   4.75
#
# [127 rows x 2 columns]

# %%
prime_calc = prime_df.groupby("DATE")
prime_result = prime_calc.agg({'PRIME':'mean'})
prime_result
# Out:
#           PRIME
# DATE
# 1982  14.583333
# 1983  10.833333
# 1984  12.000000
# 1985  10.000000
# 1986   8.250000
# 1987   8.535714
# 1988   9.500000
# 1989  11.000000
# 1990  10.000000
# 1991   8.166667
# 1992   6.000000
# 1994   7.300000
# 1995   8.750000
# 1996   8.250000
# 1997   8.500000
# 1998   8.000000
# 1999   8.250000
# 2000   9.083333
# 2001   6.772727
# 2002   4.250000
# 2003   4.000000
# 2004   4.750000
# 2005   6.375000
# 2006   7.875000
# 2007   7.500000
# 2008   4.928571
# 2015   3.500000
# 2016   3.750000
# 2017   4.250000
# 2018   5.125000
# 2019   5.000000

# %%
prime_result.reset_index(inplace=True)
prime_result
# Out:
#     DATE      PRIME
# 0   1982  14.583333
# 1   1983  10.833333
# 2   1984  12.000000
# 3   1985  10.000000
# 4   1986   8.250000
# 5   1987   8.535714
# 6   1988   9.500000
# 7   1989  11.000000
# 8   1990  10.000000
# 9   1991   8.166667
# 10  1992   6.000000
# 11  1994   7.300000
# 12  1995   8.750000
# 13  1996   8.250000
# 14  1997   8.500000
# 15  1998   8.000000
# 16  1999   8.250000
# 17  2000   9.083333
# 18  2001   6.772727
# 19  2002   4.250000
# 20  2003   4.000000
# 21  2004   4.750000
# 22  2005   6.375000
# 23  2006   7.875000
# 24  2007   7.500000
# 25  2008   4.928571
# 26  2015   3.500000
# 27  2016   3.750000
# 28  2017   4.250000
# 29  2018   5.125000
# 30  2019   5.000000

# %%
prime_result.dtypes
# Out:
# DATE       int64
# PRIME    float64
# dtype: object

# %%
type(prime_result)
# Out:
# pandas.core.frame.DataFrame

# %%
# Combining imp_df and prime_df
imp_df.dtypes
# Out:
# BATHRM          int64
# HF_BATHRM       int64
# AC             object
# ROOMS           int64
# BEDRM           int64
# STORIES       float64
# SALEDATE      float64
# KITCHENS      float64
# FIREPLACES      int64
# LANDAREA        int64
# LONGITUDE     float64
# LATITUDE      float64
# QUADRANT       object
# PRICE         float64
# ZIPCODE       float64
# dtype: object

# %%
imp_df['SALEDATE'] = imp_df['SALEDATE'].astype(int)
imp_df.dtypes
# Out:
# BATHRM          int64
# HF_BATHRM       int64
# AC             object
# ROOMS           int64
# BEDRM           int64
# STORIES       float64
# SALEDATE        int32
# KITCHENS      float64
# FIREPLACES      int64
# LANDAREA        int64
# LONGITUDE     float64
# LATITUDE      float64
# QUADRANT       object
# PRICE         float64
# ZIPCODE       float64
# dtype: object

# %%
# Renaming column for merge
prime_result = prime_result.rename(columns={'DATE': 'SALEDATE', 'PRIME': 'PRIME'})
prime_result.columns
# Out:
# Index(['SALEDATE', 'PRIME'], dtype='object')

# %%
merged_df = pd.merge(imp_df, prime_result, how = 'left', on='SALEDATE')
merged_df.head(20)
# Out:
#     BATHRM  HF_BATHRM AC  ROOMS  BEDRM  STORIES  SALEDATE  KITCHENS  \
# 0        4          0  Y      8      4      3.0      2003       2.0
# 1        3          1  Y      9      5      3.0      2016       2.0
# 2        3          1  Y      8      5      3.0      2006       2.0
# 3        3          2  Y     10      5      4.0      2010       1.0
# 4        3          1  Y      8      4      3.0      2011       2.0
# 5        3          1  Y      7      3      2.0      2018       2.0
# 6        3          1  Y      5      3      2.0      2011       2.0
# 7        3          1  Y      8      3      2.0      2010       1.0
# 8        3          1  Y      9      3      2.0      2001       2.0
# 9        3          1  Y     14      5      3.0      2016       1.0
# 10       1          0  Y      6      3      2.0      2006       1.0
# 11       2          1  Y      5      3      2.0      2012       1.0
# 12       2          1  Y      8      3      2.0      2012       1.0
# ...

# %%
merged_df['PRIME'] = merged_df['PRIME'].replace(np.nan, 3.25)
merged_df.head(10)
# Out:
#    BATHRM  HF_BATHRM AC  ROOMS  BEDRM  STORIES  SALEDATE  KITCHENS  \
# 0       4          0  Y      8      4      3.0      2003       2.0
# 1       3          1  Y      9      5      3.0      2016       2.0
# 2       3          1  Y      8      5      3.0      2006       2.0
# 3       3          2  Y     10      5      4.0      2010       1.0
# 4       3          1  Y      8      4      3.0      2011       2.0
# 5       3          1  Y      7      3      2.0      2018       2.0
# 6       3          1  Y      5      3      2.0      2011       2.0
# 7       3          1  Y      8      3      2.0      2010       1.0
# 8       3          1  Y      9      3      2.0      2001       2.0
# 9       3          1  Y     14      5      3.0      2016       1.0
#
#    FIREPLACES  LANDAREA  LONGITUDE   LATITUDE QUADRANT      PRICE  ZIPCODE  \
# 0           5      1680 -77.040832  38.914680       NW  1095000.0  20009.0
# 1           4      1680 -77.040678  38.914684       NW  2100000.0  20009.0
# ...

# %%
sns.pairplot(merged_df[['ROOMS','BATHRM','HF_BATHRM','BEDRM','KITCHENS', 'FIREPLACES']], kind="scatter", diag_kind = 'kde', plot_kws = {'alpha': 0.33, 's': 80, 'edgecolor': 'k'}, size = 4)
plt.show()
# Out:
# C:\Users\FrantheMan\anaconda3\envs\mlenv\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
school_data = pd.read_csv('Raw Data/DC_High_School_Rankings.csv')
school_df = pd.DataFrame(school_data)
school_df
# Out:
#     Rank (2018-19)                                             School  \
# 0                1                      Benjamin Banneker High School
# 1                2                   School Without Walls High School
# 2                3                Washington Latin PCS - Upper School
# 3                4                    McKinley Technology High School
# 4                5                      Thurgood Marshall Academy PCS
# 5                6                         Woodrow Wilson High School
# 6                7                                       Basis Dc Pcs
# 7                8                  KIPP DC - College Preparatory PCS
# 8                9                  Duke Ellington School of the Arts
# 9               10  Friendship PCS - Technology Preparatory High S...
# 10              11                  Columbia Heights Education Campus
# 11              12               Paul PCS - International High School
# ...

# %%
school_df.Zip.value_counts()
# Out:
# 20011    7
# 20019    6
# 20001    3
# 20002    3
# 20032    3
# 20020    2
# 20037    1
# 20016    1
# 20004    1
# 20007    1
# 20010    1
# 20024    1
# 20003    1
# 20009    1
# Name: Zip, dtype: int64

# %%
imp_school_df = school_df[['Rank (2018-19)','School', 'Zip']]
imp_school_df.head()
# Out:
#    Rank (2018-19)                               School    Zip
# 0               1        Benjamin Banneker High School  20001
# 1               2     School Without Walls High School  20037
# 2               3  Washington Latin PCS - Upper School  20011
# 3               4      McKinley Technology High School  20002
# 4               5        Thurgood Marshall Academy PCS  20020

# %%
imp_school_df.dtypes
# Out:
# Rank (2018-19)     int64
# School            object
# Zip                int64
# dtype: object

# %%
imp_school_df['Zip'] = imp_school_df['Zip'].astype(int)
imp_school_df.dtypes
# Out:
# C:\Users\FrantheMan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Rank (2018-19)     int64
# School            object
# Zip                int32
# dtype: object

# %%
zip_df = imp_school_df.sort_values('Zip')
zip_df.head(50)
# Out:
#     Rank (2018-19)                                             School    Zip
# 0                1                      Benjamin Banneker High School  20001
# 23              24                                 Dunbar High School  20001
# 31              32                Washington Metropolitan High School  20001
# 3                4                    McKinley Technology High School  20002
# 7                8                  KIPP DC - College Preparatory PCS  20002
# 15              16  Phelps Architecture Construction and Engineeri...  20002
# 19              20                                Eastern High School  20003
# 6                7                                       Basis Dc Pcs  20004
# 8                9                  Duke Ellington School of the Arts  20007
# 27              28                           Cardozo Education Campus  20009
# 10              11                  Columbia Heights Education Campus  20010
# ...

# %%
house_df = merged_df['ZIPCODE']== 20011
house_df.value_counts()
# Out:
# False    50239
# True      7525
# Name: ZIPCODE, dtype: int64
